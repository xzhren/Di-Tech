# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
track = pd.read_csv("../input/track.txt")
track['id'] = track['vehicle-id']
track['x'] = track['x-coordinate']
track['y'] = track['y-coordinate']
del track['nan']
del track['vehicle-id']
del track['x-coordinate']
del track['y-coordinate']
# track = track.set_index('vehicle-id')
track.head()
# Out:
#          time  speed  category                                id  \
# 0  1493859164    6.6         0  4c0c4745067197be22182d262b44f48a
# 1  1493859167    6.1         0  4c0c4745067197be22182d262b44f48a
# 2  1493859170    6.2         0  4c0c4745067197be22182d262b44f48a
# 3  1493859173    6.9         0  4c0c4745067197be22182d262b44f48a
# 4  1493859176    7.2         0  4c0c4745067197be22182d262b44f48a
#
#                x             y
# 0  521696.473915  55061.506951
# 1  521680.892788  55051.685121
# 2  521665.311690  55041.863291
# 3  521648.617687  55030.255674
# 4  521628.584926  55019.540951

# %%
vid = []
tmpid = ''
adddollar = False

for id in track.id.values:
    if id == tmpid:
        if adddollar:
            vid.append(id+'$')
        else:
            vid.append(id)
    elif id in vid:
        print("12345678987654323456789987654321")
        adddollar = False
        id = id+'$'
        vid.append(id)
        tmpid = id
        adddollar = True
    else:
        adddollar = False
        vid.append(id)
        tmpid = id

# %%
track['vid'] = vid

# %%
len(set(track.id)), len(set(track.vid)),
# Out:
# (5415, 5415)

# %%
track[track.speed >30]
# Out:
#               time  speed  category                                id  \
# 6114    1493858327   45.5         1  aeb0af07123eb63cd033f592e96c014f
# 16746   1493858687   30.4         0  f29574c88345533a8704a3903071d056
# 21744   1493858837   30.3         1  863f391a3e9e5f0d3e04a52cc07c5dbf
# 43595   1493858592   41.8         1  c8c716302a97e276d1c89a64cdddf5dd
# 43600   1493858631   55.3         1  c8c716302a97e276d1c89a64cdddf5dd
# 45719   1493858134   62.9         1  6e954df493d4615ccd6500323953c53f
# 61447   1493858420   31.8         0  3c1dbccaa56548aa354a56b715c3b42c
# 75743   1493940723   33.9         1  f93f85bdf3a301271aeb4817bf758550
# 78570   1493944824   35.3         1  152ae3e61da757618e9139e18c2aed1c
# 81984   1493940723   34.8         1  9021d77e26b6a27b7eeba0c804098c44
# 81993   1493940759   32.2         1  9021d77e26b6a27b7eeba0c804098c44
# 94326   1493945243   37.3         1  81cb3974054279c198dca7c21d71cf04
# ...

# %%
track = track.sort_values(by=['time'])

# %%
track.describe()
# Out:
#                time          speed       category              x  \
# count  6.093950e+05  609395.000000  609395.000000  609395.000000
# mean   1.494441e+09       4.533246       0.895272  521468.436217
# std    3.632164e+05       5.307853       0.306203     110.134664
# min    1.493852e+09       0.000000       0.000000  520955.288814
# 25%    1.494203e+09       0.000000       1.000000  521411.566353
# 50%    1.494458e+09       2.100000       1.000000  521431.598606
# 75%    1.494807e+09       8.700000       1.000000  521537.325164
# max    1.494983e+09     101.800000       1.000000  521920.177507
#
#                    y
# count  609395.000000
# mean    55857.294875
# std      1395.999743
# min     53380.188236
# 25%     54790.067286
# 50%     55736.534540
# 75%     57083.911036
# max     58715.227708

# %%
len(set(track.id))
# Out:
# 5415

# %%
plt.figure(figsize=(10,10))
for id in list(set(track.id))[:500]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
#     plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
plt.plot(x,y,'ro',label="point")
plt.show()

# %%
plt.figure(figsize=(10,10))
for id in list(set(track.id))[6:7]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
    x = track[(track.id == id) & (track.speed < 1)]['x'].values
    y = track[(track.id == id) & (track.speed < 1)]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
plt.plot(x,y,'ro',label="point")
plt.show()

# %%
plt.figure(figsize=(10,10))
for id in list(set(track.id))[6:7]:
#     x = track[track.id == id]['x'].values
#     y = track[track.id == id]['y'].values
#     plt.scatter(x,y)
#     plt.plot(x,y)
    x = track[(track.id == id) & (track.speed < 1)]['x'].values
    y = track[(track.id == id) & (track.speed < 1)]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
# x = [521677,521580,521520,521452,521433,521411,521400]
# y = [58109,57466,57059,56668,55855,54822,53998]
plt.plot(x,y,'ro',label="point")
plt.show()

# %%
id = list(set(track.id))[6:7][0]
track[track.id == id]
track[(track.id == id) & (track.speed < 1)]
# 259329	1494374827	0.0	1	e7157156d650268aec56e0d200c11c1b	521420.469571	54729.350519	e7157156d650268aec56e0d200c11c1b
# 259362
track.iloc[(259329):(259362+3), :]
# track.iloc[:, :]
# Out:
#               time  speed  category                                id  \
# 259329  1494374827    0.0         1  e7157156d650268aec56e0d200c11c1b
# 259330  1494374830    4.2         1  e7157156d650268aec56e0d200c11c1b
# 259331  1494374833    3.9         1  e7157156d650268aec56e0d200c11c1b
# 259332  1494374836    6.7         1  e7157156d650268aec56e0d200c11c1b
# 259333  1494374839    5.7         1  e7157156d650268aec56e0d200c11c1b
# 259334  1494374842    6.9         1  e7157156d650268aec56e0d200c11c1b
# 259335  1494374845    7.2         1  e7157156d650268aec56e0d200c11c1b
# 259336  1494374848    7.2         1  e7157156d650268aec56e0d200c11c1b
# 259337  1494374851    5.8         1  e7157156d650268aec56e0d200c11c1b
# 259338  1494374854    5.0         1  e7157156d650268aec56e0d200c11c1b
# 259339  1494374857    6.8         1  e7157156d650268aec56e0d200c11c1b
# 259340  1494374659    6.3         1  e7157156d650268aec56e0d200c11c1b
# ...

# %%
plt.figure(figsize=(10,10))

plt.subplot(331)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[0]-50,x[0]+50])  
axes.set_ylim([y[0]-50,y[0]+50])  
plt.plot(x,y,'ro',label="point")

plt.subplot(332)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[1]-50,x[1]+50])  
axes.set_ylim([y[1]-50,y[1]+50])    
plt.plot(x,y,'ro',label="point")

plt.subplot(333)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[2]-50,x[2]+50])  
axes.set_ylim([y[2]-50,y[2]+50])    
plt.plot(x,y,'ro',label="point")

plt.subplot(334)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[3]-50,x[3]+50])  
axes.set_ylim([y[3]-50,y[3]+50])    
plt.plot(x,y,'ro',label="point")

plt.subplot(335)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[4]-50,x[4]+50])  
axes.set_ylim([y[4]-50,y[4]+50])    
plt.plot(x,y,'ro',label="point")

plt.subplot(336)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[5]-50,x[5]+50])  
axes.set_ylim([y[5]-50,y[5]+50])    
plt.plot(x,y,'ro',label="point")

plt.subplot(337)
for id in list(set(track.id))[:50]:
    x = track[track.id == id]['x'].values
    y = track[track.id == id]['y'].values
    plt.scatter(x,y)
    plt.plot(x,y)
x = [521677,521580,521520,521452,521433,521411,521400]
y = [58109,57466,57059,56668,55855,54822,53998]
axes = plt.gca()  
axes.set_xlim([x[6]-50,x[6]+50])  
axes.set_ylim([y[6]-50,y[6]+50])    
plt.plot(x,y,'ro',label="point")

plt.show()
